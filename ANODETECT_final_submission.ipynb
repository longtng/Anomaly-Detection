# %% [markdown]
# <b>AML2019</b>

# %% [markdown]
# # GROUP 22
# - **NGUYEN Thanh-Long**
# - **DANG Ngoc-Vien**

# %% [markdown]
# %%html
# <style>
#     table { display: inline-block }
#     td { font-size: 10.5px;  }
#     th { font-size: 12px; }
# </style>

# %% [markdown]
# <h3>Challenge 3</h3>
# <h1>Anomaly Detection (AD)</h1>
# <hr style="height:2px;border:none;color:#333;background-color:#333;"/>
# <i>3<sup>th</sup> May 2019</i>

# %% [markdown]
# Anomaly detection (AD) refers to the process of detecting data points that do not conform with the rest of observations. Applications of anomaly detection include fraud and fault detection, surveillance, diagnosis, data cleanup, predictive maintenance.
#
# When we talk about AD, we usually look at it as an unsupervised (or semi-supervised) task, where the concept of anomaly is often not well defined or, in the best case, just few samples are labeled as anomalous. In this challenge, you will look at AD from a different perspective!
#
# The dataset you are going to work on consists of monitoring data generated by IT systems; such data is then processed by a monitoring system that executes some checks and detects a series of anomalies. This is a multi-label classification problem, where each check is a binary label corresponding to a specific type of anomaly. Your goal is to develop a machine learning model (or multiple ones) to accurately detect such anomalies.
#
# This will also involve a mixture of data exploration, pre-processing, model selection, and performance evaluation. You will also be asked to try one or more rule learning models, and compare them with other ML models both in terms of predictive performances and interpretability. Interpreatibility is indeed a strong requirement especially in applications like AD where understanding the output of a model is as important as the output itself.
#
# Please, bear in mind that the purpose of this challenge is not simply to find the best-performing model. You should rather make sure to understand the difficulties that come with this AD task.

# %% [markdown]
# # Overview
# <hr style="height:1px;border:none;color:#333;background-color:#333;" />

# %% [markdown]
# Beyond simply producing a well-performing model for making predictions, in this challenge we would like you to start developing your skills as a machine learning scientist.
# In this regard, your notebook should be structured in such a way as to explore the five following tasks that are expected to be carried out whenever undertaking such a project.
# The description below each aspect should serve as a guide for your work, but you are strongly encouraged to also explore alternative options and directions.
# Thinking outside the box will always be rewarded in these challenges.

# %% [markdown]
# <div class="">
#     <h3>1. Data Exploration</h3>
# </div>

# %% [markdown]
# The first broad component of your notebook should enable you to familiarise yourselves with the given data, an outline of which is given at the end of this challenge specification.
# Among others, this section should investigate:
#
# - Data cleaning
# - Data visualisation;
# - Computing descriptive statistics, e.g. correlation.
# - etc.
#
# Data exploration is also useful to identify eventual errors in the dataset: for example, some features may have values that are outside the allowed range of values. Ranges are specified in the dataset description.

# %% [markdown]
# <div class="">
#     <h3>2. Data Pre-processing</h3>
# </div>

# %% [markdown]
# The previous step should give you a better understanding of which pre-processing is required for the data.
# This may include:
#
# - Normalising and standardising the given data;
# - Removing outliers;
# - Carrying out feature selection;
# - Handling missing information in the dataset;
# - Handling errors in the dataset;
# - Combining existing features.

# %% [markdown]
# <div class="">
#     <h3>3. Model Selection</h3>
# </div>

# %% [markdown]
# At this point, you should have a good understanding of the dataset, and have an idea about the possible candidate models. For example, you may try a multi-label classification model to predict all classes at ones, or train different models, one for each label. In any case, it is important to justify your choices and make a comparison among the candidate models.
#
# You are free to choose any model you want, but you should be aware about some factors which may influence your decision:
#
# - What is the model's complexity?
# - Is the model interpretable?
# - Is the model able to handle imbalanced datasets?
# - Is the model capable of handling both numerical and categorical data?
# - Is the model able to handle missing values?
# - Does the model return uncertainty estimates along with predictions?
#
# An in-depth evaluation of competing models in view of this and other criteria will elevate the quality of your submission and earn you a higher grade. You may also try to build new labels by combining one or more labels (for example by doing an OR) and check if this impacts the performance of the model(s).

# %% [markdown]
# <div class="">
#     <h4>3.1 Interpretable Models</h3>
# </div>

# %% [markdown]
# Being able to understand the output of a model is important in many field, especially in anomaly detection. In linear regression, for example, the weights of the model can provide some hints on the importance of features, and this is a form of interpretability. Here, we focus on Rule learning, a specific field of interpretable machine learning that provides interpretability through the use of rules. Examples of rule-based models are:
#
# - RIPPER
#     - [Main Paper](http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.107.2612&rep=rep1&type=pdf)
#     - A fast and reliable implementation is JRIP by [WEKA](https://www.cs.waikato.ac.nz/~ml/weka/). You can also find unofficial python implementations on GitHub.
# - Bayesian Rule Sets (BRS)
#     - [Main Paper](http://jmlr.org/papers/volume18/16-003/16-003.pdf)
#     - You can find a good implementation [here](https://pypi.org/project/ruleset/). You will probably need to install "fim" (pip install fim) before installing BRS.
# - Scalable Bayesian Rule Lists (SBRL)
#     - [Main Paper](https://arxiv.org/pdf/1602.08610.pdf)
#     - You can find a good implementation [here](https://github.com/myaooo/pysbrl). You will probably need to install "fim" (pip install fim) before installing SBRL.
# - and so on...
#
# Try to run at least one of the suggested models (you are free to try others as well) and comment:
#
# - Are rule-learning models able to provide the same predictive performances as previously tested models?
# - Are they faster or slower to train?
# - Do learned rules look meaningful to you?
# - How many rules do these models learn?
# - How many conditions/atoms have on average?
#
# <b>N.B.</b> Since most of the rule-learning implementations deal with binary labels, you can train the model to predict one label of your choice.

# %% [markdown]
# <div class="">
#     <h3>4. Parameter Optimisation</h3>
# </div>

# %% [markdown]
# Irrespective of your choice, it is highly likely that your model will have one or more parameters that require tuning.
# There are several techniques for carrying out such a procedure, including cross-validation, Bayesian optimisation, and several others.
# As before, an analysis into which parameter tuning technique best suits your model is expected before proceeding with the optimisation of your model.

# %% [markdown]
# <div class="">
#     <h3>5. Model Evaluation</h3>
# </div>

# %% [markdown]
# Some form of pre-evaluation will inevitably be required in the preceding sections in order to both select an appropriate model and configure its parameters appropriately.
# In this final section, you may evaluate other aspects of the model such as:
#
# - Assessing the running time of your model;
# - Determining whether some aspects can be parallelised;
# - Training the model with smaller subsets of the data.
# - etc.
#
# For the evaluation of the classification results, you should use F1-score for each class and do the average.
#
# <b>N.B.</b> Please note that you are responsible for creating a sensible train/validation/test split. There is no predefined held-out test data.

# %% [markdown]
# <div class="">
#     <h3>*. Optional</h3>
# </div>

# %% [markdown]
# As you will see in the dataset description, the labels you are going to predict have no meaningful names. Try to understand which kind of anomalies these labels refer to and give sensible names. To do it, you could exploit the output of the interpretable models and/or use a statistical approach with the data you have.

# %% [markdown]
# <div class="alert alert-danger">
#     <b>N.B.</b> Please note that the items listed under each heading are neither exhaustive, nor are you expected to explore every given suggestion.
#     Nonetheless, these should serve as a guideline for your work in both this and upcoming challenges.
#     As always, you should use your intuition and understanding in order to decide which analysis best suits the assigned task.
# </div>

# %% [markdown]
# <div class="">
#     <h2>Submission Instructions</h2>
#     <hr style="height:1px;border:none;color:#333;background-color:#333;" />
# </div>

# %% [markdown]
# - The goal of this challenge is to construct one or more models to detect anomalies.
# - Your submission will be the <b>HTML version of your notebook</b> exploring the various modelling aspects described above.

# %% [markdown]
# <div class="">
#     <h2>Dataset Description</h2>
#     <hr style="height:1px;border:none;color:#333;background-color:#333;"/>
# </div>

# %% [markdown]
# #### * Location of the Dataset on zoe
# The data for this challenge is located at: `/mnt/datasets/anomaly`
#
# #### * Files
#
# You have a unique csv file with 36 features and 8 labels.
# Each record contains aggregate features computed over a given amount of time.
#
# #### * Attributes
#
# A brief outline of the available attributes is given below.
#
# 1. <i>SessionNumber</i> (INTEGER): it identifies the session on which data is collected;
# * <i>SystemID</i> (INTEGER): it identifies the system generating the data;
# * <i>Date</i> (DATE): collection date;
# * <i>HighPriorityAlerts</i> (INTEGER [0, N]): number of high priority alerts in the session;
# * <i>Dumps</i> (INTEGER [0, N]): number of memory dumps;
# * <i>CleanupOOMDumps</i> (INTEGER) [0, N]): number of cleanup OOM dumps;
# * <i>CompositeOOMDums</i> (INTEGER [0, N]): number of composite OOM dumps;
# * <i>IndexServerRestarts</i> (INTEGER [0, N]): number of restarts of the index server;
# * <i>NameServerRestarts</i> (INTEGER [0, N]): number of restarts of the name server;
# * <i>XSEngineRestarts</i> (INTEGER [0, N]): number of restarts of the XSEngine;
# * <i>PreprocessorRestarts</i> (INTEGER [0, N]): number of restarts of the preprocessor;
# * <i>DaemonRestarts</i> (INTEGER [0, N]): number of restarts of the daemon process;
# * <i>StatisticsServerRestarts</i> (INTEGER [0, N]): number of restarts of the statistics server;
# * <i>CPU</i> (FLOAT [0, 100]): cpu usage;
# * <i>PhysMEM</i> (FLOAT [0, 100]): physical memory;
# * <i>InstanceMEM</i> (FLOAT [0, 100]): memory usage of one instance of the system;
# * <i>TablesAllocation</i> (FLOAT [0, 100]): memory allocated for tables;
# * <i>IndexServerAllocationLimit</i> (FLOAT [0, 100]): level of memory used by index server;
# * <i>ColumnUnloads</i> (INTEGER [0, N]): number of columns unloaded from the tables;
# * <i>DeltaSize</i> (INTEGER [0, N]): size of the delta store;
# * <i>MergeErrors</i> BOOLEAN [0, 1]: 1 if there are merge errors;
# * <i>BlockingPhaseSec</i> (INTEGER [0, N]): blocking phase duration in seconds;
# * <i>Disk</i> (FLOAT [0, 100]): disk usage;
# * <i>LargestTableSize</i> (INTEGER [0, N]): size of the largest table;
# * <i>LargestPartitionSize</i> (INTEGER [0, N]): size of the largest partition of a table;
# * <i>DiagnosisFiles</i> (INTEGER [0, N]): number of diagnosis files;
# * <i>DiagnosisFilesSize</i> (INTEGER [0, N]): size of diagnosis files;
# * <i>DaysWithSuccessfulDataBackups</i> (INTEGER [0, N]): number of days with successful data backups;
# * <i>DaysWithSuccessfulLogBackups</i> (INTEGER [0, N]): number of days with successful log backups;
# * <i>DaysWithFailedDataBackups</i> (INTEGER [0, N]): number of days with failed data backups;
# * <i>DaysWithFailedfulLogBackups</i> (INTEGER [0, N]): number of days with failed log backups;
# * <i>MinDailyNumberOfSuccessfulDataBackups</i> (INTEGER [0, N]): minimum number of successful data backups per day;
# * <i>MinDailyNumberOfSuccessfulLogBackups</i> (INTEGER [0, N]): minimum number of successful log backups per day;
# * <i>MaxDailyNumberOfFailedDataBackups</i> (INTEGER [0, N]): maximum number of failed data backups per day;
# * <i>MaxDailyNumberOfFailedLogBackups</i> (INTEGER [0, N]): maximum number of failed log backups per day;
# * <i>LogSegmentChange</i> (INTEGER [0, N]): changes in the number of log segments.
#
# #### * Labels
#
# Labels are binary. Each label refers to a different anomaly.
#
# * <i>Check1</i>;
# * <i>Check2</i>;
# * <i>Check3</i>;
# * <i>Check4</i>;
# * <i>Check5</i>;
# * <i>Check6</i>;
# * <i>Check7</i>;
# * <i>Check8</i>;

# %%
# !apt-get -qq install -y fim

# %%
# !pip install -q  ruleset

# %%
import ruleset as rs

# %%
import pandas as pd
import numpy as np
import missingno as msno # Missingno package for visualizing missing data
from collections import Counter

import xgboost as xgb
from xgboost import XGBClassifier

from sklearn import preprocessing
from sklearn.datasets import make_classification
from imblearn.over_sampling import SMOTE # doctest: +NORMALIZE_WHITESPACE
from imblearn.under_sampling import RandomUnderSampler
from sklearn.metrics import f1_score
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, KFold, train_test_split

import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import seaborn as sns
# %matplotlib inline
plt.style.use(style='ggplot')
plt.rcParams['figure.figsize'] = (10, 6)

# %%
# Links of dataset 
urldata = 'https://raw.githubusercontent.com/longtng/Anomaly-Detection/master/Data/data.csv'
urlhead = 'https://raw.githubusercontent.com/longtng/Anomaly-Detection/master/Data/header.csv'

# %%
#Processing the column names first
temphead = pd.read_csv(urlhead, header=None, names = list(range(0,100))) #the header dataframe

# %%
temphead.head()
# Out:
#                                                   0   ...  99
# 0  SessionNumber (INTEGER): it identifies the ses...  ... NaN
# 1  SystemID (INTEGER): it identifies the system g...  ... NaN
# 2                      Date (DATE): collection date;  ... NaN
# 3                     HighPriorityAlerts (INTEGER [0  ... NaN
# 4                                  Dumps (INTEGER [0  ... NaN
#
# [5 rows x 100 columns]

# %%
# get the columns name from head to temp
columnsname = temphead[0].copy() #all columns
for row in range(0,len(temphead)):
  columnsname[row] = (temphead[0][row].split(' ', 1)[0]) #get the feature name by getting the first word in string
columnsname = columnsname.values #convert to array
columnsname
# Out:
# array(['SessionNumber', 'SystemID', 'Date', 'HighPriorityAlerts', 'Dumps',
#        'CleanupOOMDumps', 'CompositeOOMDums', 'IndexServerRestarts',
#        'NameServerRestarts', 'XSEngineRestarts', 'PreprocessorRestarts',
#        'DaemonRestarts', 'StatisticsServerRestarts', 'CPU', 'PhysMEM',
#        'InstanceMEM', 'TablesAllocation', 'IndexServerAllocationLimit',
#        'ColumnUnloads', 'DeltaSize', 'MergeErrors', 'BlockingPhaseSec',
#        'Disk', 'LargestTableSize', 'LargestPartitionSize',
#        'DiagnosisFiles', 'DiagnosisFilesSize',
#        'DaysWithSuccessfulDataBackups', 'DaysWithSuccessfulLogBackups',
#        'DaysWithFailedDataBackups', 'DaysWithFailedfulLogBackups',
#        'MinDailyNumberOfSuccessfulDataBackups',
#        'MinDailyNumberOfSuccessfulLogBackups',
#        'MaxDailyNumberOfFailedDataBackups',
#        'MaxDailyNumberOfFailedLogBackups', 'LogSegmentChange', 'Check1',
#        'Check2', 'Check3', 'Check4', 'Check5', 'Check6', 'Check7',
# ...

# %%
#Read the dataset
df = pd.read_csv(urldata, sep=';', header=None, names=columnsname) #the data set

normcolumns = (df.columns)[3:36] #Normal columns name index
classcolumns = (df.columns)[36:] #Classes columns name index

# %%
display(df.head())
display(df.shape)
df.info()
# Out:
#    SessionNumber  SystemID              Date  ...  Check6  Check7  Check8
# 0              0         0  16/01/2017 04:04  ...     0.0     0.0     0.0
# 1              1         1  06/02/2017 04:03  ...     0.0     0.0     0.0
# 2              2         1  20/02/2017 04:03  ...     0.0     0.0     0.0
# 3              3         2  13/02/2017 04:44  ...     0.0     0.0     0.0
# 4              4         3  06/02/2017 04:31  ...     0.0     0.0     0.0
#
# [5 rows x 44 columns]
# (287031, 44)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 287031 entries, 0 to 287030
# Data columns (total 44 columns):
# SessionNumber                            287031 non-null int64
# SystemID                                 287031 non-null int64
# Date                                     287031 non-null object
# HighPriorityAlerts                       287031 non-null int64
# Dumps                                    287028 non-null float64
# ...

# %%
def missingcheck(df):
    total = df.isnull().sum()#.sort_values(ascending=False)
    percent = (df.isnull().sum()/df.isnull().count()*100)#.sort_values(ascending=False)
    missing = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
    missing = missing[missing['Total']>0]
    print("The below table of the attributes having missing values and percentages of non-missing values of these attributes:")
    print()
    print(missing.sort_values(by=['Percent'],ascending=False))
    print()
    print("The number of attributes have missing values are", len(missing))
    return missing;

# %%
#check missing
missing = missingcheck(df)
# Out:
# The below table of the attributes having missing values and percentages of non-missing values of these attributes:
#
#                             Total    Percent
# BlockingPhaseSec            75854  26.427111
# Check4                      36647  12.767610
# Check7                      35722  12.445346
# LogSegmentChange            35549  12.385073
# Check5                      35034  12.205650
# IndexServerAllocationLimit  26444   9.212942
# CPU                         25209   8.782675
# Check1                      24511   8.539496
# Check2                      24486   8.530786
# Check3                      22568   7.862565
# InstanceMEM                 22117   7.705439
# DiagnosisFiles              21923   7.637851
# DiagnosisFilesSize          21923   7.637851
# PhysMEM                     20567   7.165428
# LargestTableSize            16250   5.661409
# Disk                        11379   3.964380
# MergeErrors                  7733   2.694134
# ...

# %%
plt.subplots(figsize =(15, 6))
# %matplotlib inline
msno.matrix(df[missing.index])

# %%
#Drop Missing values on multi-classes
df = df.dropna(subset=classcolumns) 
display(df.shape)
df.head()
# Out:
# (236611, 44)
#     SessionNumber  SystemID              Date  ...  Check6  Check7  Check8
# 74             70        15  16/01/2017 04:33  ...     0.0     0.0     0.0
# 75             71        16  16/01/2017 04:19  ...     0.0     0.0     0.0
# 76             72        17  16/01/2017 04:35  ...     0.0     0.0     0.0
# 77             73        18  16/01/2017 04:46  ...     0.0     0.0     0.0
# 78             74        19  16/01/2017 04:27  ...     0.0     0.0     0.0
#
# [5 rows x 44 columns]

# %%
#check missing values again:
missing = missingcheck(df)
# Out:
# The below table of the attributes having missing values and percentages of non-missing values of these attributes:
#
#                             Total    Percent
# BlockingPhaseSec            34127  14.423252
# DiagnosisFiles               4072   1.720968
# DiagnosisFilesSize           4072   1.720968
# Disk                         3023   1.277624
# CPU                          2157   0.911623
# LargestTableSize              107   0.045222
# LogSegmentChange               21   0.008875
# LargestPartitionSize           20   0.008453
# DeltaSize                      18   0.007607
# PhysMEM                         3   0.001268
# InstanceMEM                     3   0.001268
# Dumps                           2   0.000845
# CleanupOOMDumps                 2   0.000845
# CompositeOOMDums                2   0.000845
# IndexServerAllocationLimit      2   0.000845
#
# The number of attributes have missing values are 15

# %%
#Fill all missing values with the median values 
for col in missing.index:
  fillupvalue = df[col].dropna().median()
  df.loc[df[col].isnull(),col] = fillupvalue

# %%
#check missing values again
missingcheck(df)
# Out:
# The below table of the attributes having missing values and percentages of non-missing values of these attributes:
#
# Empty DataFrame
# Columns: [Total, Percent]
# Index: []
#
# The number of attributes have missing values are 0
# Empty DataFrame
# Columns: [Total, Percent]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 236611 entries, 74 to 287022
# Data columns (total 44 columns):
# SessionNumber                            236611 non-null int64
# SystemID                                 236611 non-null int64
# Date                                     236611 non-null object
# HighPriorityAlerts                       236611 non-null int64
# Dumps                                    236611 non-null float64
# CleanupOOMDumps                          236611 non-null float64
# CompositeOOMDums                         236611 non-null float64
# IndexServerRestarts                      236611 non-null int64
# NameServerRestarts                       236611 non-null int64
# XSEngineRestarts                         236611 non-null int64
# PreprocessorRestarts                     236611 non-null int64
# DaemonRestarts                           236611 non-null int64
# StatisticsServerRestarts                 236611 non-null int64
# ...

# %%
# %%time
#convert the features types back to its default types. 
columnstype = temphead[0].copy()
for row in range(0,len(temphead)):
  #ktemp=temp[0][row].split('(', 1)[1]
  if temphead[0][row].find('FLOAT') != -1:
    df.iloc[:,row] = df.iloc[:,row].astype(float)
  elif temphead[0][row].find('DATE') != -1:
    df.iloc[:,row]=pd.to_datetime(df.iloc[:,row])
  else:
    df.iloc[:,row] = df.iloc[:,row].astype(int)
# Out:
# CPU times: user 35.8 s, sys: 28.8 ms, total: 35.8 s
# Wall time: 35.8 s

# %%
#check the data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 236611 entries, 74 to 287022
# Data columns (total 44 columns):
# SessionNumber                            236611 non-null int64
# SystemID                                 236611 non-null int64
# Date                                     236611 non-null datetime64[ns]
# HighPriorityAlerts                       236611 non-null int64
# Dumps                                    236611 non-null int64
# CleanupOOMDumps                          236611 non-null int64
# CompositeOOMDums                         236611 non-null int64
# IndexServerRestarts                      236611 non-null int64
# NameServerRestarts                       236611 non-null int64
# XSEngineRestarts                         236611 non-null int64
# PreprocessorRestarts                     236611 non-null int64
# DaemonRestarts                           236611 non-null int64
# StatisticsServerRestarts                 236611 non-null int64
# ...

# %%
#check all the values in dataset
df.iloc[:,3:36].sum().sort_values()
# Out:
# CleanupOOMDumps                          0.000000e+00
# PreprocessorRestarts                     0.000000e+00
# DaemonRestarts                           0.000000e+00
# StatisticsServerRestarts                 5.520000e+02
# XSEngineRestarts                         1.262500e+04
# NameServerRestarts                       1.488300e+04
# IndexServerRestarts                      2.173800e+04
# MaxDailyNumberOfFailedDataBackups        2.567900e+04
# CompositeOOMDums                         3.636600e+04
# DaysWithFailedDataBackups                4.605700e+04
# MergeErrors                              1.003990e+05
# DaysWithFailedfulLogBackups              1.317280e+05
# Dumps                                    1.497920e+05
# MinDailyNumberOfSuccessfulDataBackups    2.403190e+05
# LogSegmentChange                         3.349230e+05
# HighPriorityAlerts                       6.925820e+05
# DaysWithSuccessfulDataBackups            1.450092e+06
# ...

# %% [markdown]
# <div class="alert alert-info">
#   We can see for all of the cases, the <b>CleanupOOMDumps, PreprocessorRestarts, DaemonRestarts</b> have returned in 0, so we should drop those colunms
# </div>

# %%
df = df.drop(['CleanupOOMDumps', 'PreprocessorRestarts', 'DaemonRestarts'], axis=1) #drop columns
normcolumns = (df.columns)[3:33] #re-input normal conlumns index
display(normcolumns)
display(df.shape)
df.info()
# Out:
# Index(['HighPriorityAlerts', 'Dumps', 'CompositeOOMDums',
#        'IndexServerRestarts', 'NameServerRestarts', 'XSEngineRestarts',
#        'StatisticsServerRestarts', 'CPU', 'PhysMEM', 'InstanceMEM',
#        'TablesAllocation', 'IndexServerAllocationLimit', 'ColumnUnloads',
#        'DeltaSize', 'MergeErrors', 'BlockingPhaseSec', 'Disk',
#        'LargestTableSize', 'LargestPartitionSize', 'DiagnosisFiles',
#        'DiagnosisFilesSize', 'DaysWithSuccessfulDataBackups',
#        'DaysWithSuccessfulLogBackups', 'DaysWithFailedDataBackups',
#        'DaysWithFailedfulLogBackups', 'MinDailyNumberOfSuccessfulDataBackups',
#        'MinDailyNumberOfSuccessfulLogBackups',
#        'MaxDailyNumberOfFailedDataBackups', 'MaxDailyNumberOfFailedLogBackups',
#        'LogSegmentChange'],
#       dtype='object')
# (236611, 41)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 236611 entries, 74 to 287022
# Data columns (total 41 columns):
# ...

# %%
## CORRELATION MATRIX FOR NUMERICAL ATTRIBUTES

# BUILD THE CORRELATION MATRIX BETWEEN NUMERIC (int64 and float64) ATTRIBUTES
correlationMatrix = df[normcolumns].corr()

# PLOT THE CORRELATION MATRIX
plt.figure(figsize=(20,20))
plt.title("Correlation matrix between numerical attributes", weight="semibold")
#ax.title.set_fontsize(20)

# Build the Color Correlation Matrix
mask = np.zeros_like(correlationMatrix, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
sns.set(font_scale = 1.3)
g = sns.heatmap(correlationMatrix, cmap='Blues', fmt = '.2f', square = True, 
                mask=mask, annot=True, annot_kws={"size":10}, linewidths=1.0)

for text in g.texts:
    t = float(text.get_text())
    if ((t) < 0.65):
        text.set_text('')
    else:
        text.set_text(round(t, 4))

# Build the Values Correlation Matrix
mask[np.triu_indices_from(mask)] = False
mask[np.tril_indices_from(mask)] = True
g = sns.heatmap(correlationMatrix, cmap=ListedColormap(['white']), square = True, fmt = '.1f', 
                linewidths=1.0, mask=mask, annot=True, annot_kws={"size":10}, cbar=False);
g.set_xticklabels(g.get_xticklabels(), rotation=60, ha="right");

# %%
# %%time
# visualize the distribution of each feature
temp = pd.melt(df, value_vars=normcolumns)
plt.figure(figsize=(25,25))
sns.set(font_scale = 0.9)
grid = sns.FacetGrid(temp, col="variable",  col_wrap=4 , height=3.0, 
                     aspect=1.5,sharex=False, sharey=False)
grid.map(sns.distplot, "value",color='navy')
plt.show()
# Out:
# CPU times: user 39.7 s, sys: 6.88 s, total: 46.6 s
# Wall time: 38.4 s

# %%
#Check the distribution of output classes 
display(df[classcolumns].sum())
print("Total different classes:", df[classcolumns].sum().sum(),'\n')
display(df.shape)
df[classcolumns].sum().plot(fontsize=10)
plt.show()
# Out:
# Check1     1537
# Check2     8039
# Check3     7422
# Check4    23174
# Check5     2838
# Check6    65095
# Check7     7121
# Check8     2347
# dtype: int64
# Total different classes: 117573
# (236611, 41)

# %%
Totalanomaly = df[classcolumns].sum()
Totalnormal = df[classcolumns].count() - Totalanomaly
percent = (Totalanomaly)/(df[classcolumns].count())*100
classescheck = pd.concat([Totalanomaly,Totalnormal, percent], axis=1, keys=['Anomaly', 'Normal', '% of Anomaly'])
print("The below table showed up the imbalance between 0 and 1 outcome in each class:")
print()
print(classescheck)
# Out:
# The below table showed up the imbalance between 0 and 1 outcome in each class:
#
#         Anomaly  Normal  % of Anomaly
# Check1     1537  235074      0.649589
# Check2     8039  228572      3.397560
# Check3     7422  229189      3.136794
# Check4    23174  213437      9.794135
# Check5     2838  233773      1.199437
# Check6    65095  171516     27.511401
# Check7     7121  229490      3.009581
# Check8     2347  234264      0.991923

# %%
# We temporarily split the dataset into train and test dataset base on 'Check1' Class
X_train, X_test, y_train, y_test = train_test_split(df[normcolumns], df['Check1'].as_matrix(), test_size=0.3)

# %% [markdown]
# # Experiment with XGBOOST

# %%
def xgboostrun(X_train, X_test, y_train, y_test, weight=0):
    model1 = ()
    model1 = XGBClassifier(learning_rate =0.1,
                       scale_pos_weight = weight,
                       n_estimators=100, #by default = 100
                       max_depth=5,
                       min_child_weight=1,
                       gamma=0,
                       subsample=0.8,
                       colsample_bytree=0.8,
                       objective= 'binary:logistic',
                       nthread=1,
                       seed=27,
                       eval_metric="auc")

    model1.fit(X_train, y_train)
    
    #scoring on train set
    y_pred = model1.predict(X_train) #export class
    predictions = [round(value) for value in y_pred]
    f1mtrain = f1_score(y_train, predictions, average='macro')
    
    # scoring on test set
    y_pred = model1.predict(X_test) #export class
    predictions = [round(value) for value in y_pred]
    f1mtest = f1_score(y_test, predictions, average='macro')

    return f1mtrain, f1mtest;

# %% [markdown]
# ## First run without any imbalance processing:

# %%
# %%time 
#Not process the imbalanced classes issue
#Initiate the output metrics matrix
outputmetrics = pd.DataFrame(index=['F1 Macro on Train','F1 Macro on Test'], columns=classcolumns)

#Loop through different classes to train XGBOOST models and get F1 Macro Scores
for col in classcolumns:
    y_train, y_test = df.loc[X_train.index, col], df.loc[X_test.index, col] #get the y labels with same index as trainning set while loop through the list of classes
    
    f1mtrain, f1mtest = xgboostrun(X_train, X_test, y_train, y_test,0)
    outputmetrics.loc['F1 Macro on Train'][col] = f1mtrain*100
    outputmetrics.loc['F1 Macro on Test'][col] = f1mtest*100
# Out:
# CPU times: user 1min 20s, sys: 213 ms, total: 1min 20s
# Wall time: 1min 20s

# %%
print('The output without class imbalanced process')
outputmetrics
# Out:
# The output without class imbalanced process
#                     Check1   Check2  Check3   Check4   Check5   Check6  \
# F1 Macro on Train  49.8389   49.133  49.194  47.4232  49.6954  42.0293
# F1 Macro on Test   49.8329  49.1428  49.225  47.4306  49.7052  42.0155
#
#                     Check7   Check8
# F1 Macro on Train  49.2379  49.7509
# F1 Macro on Test   49.2319  49.7505

# %% [markdown]
# ## Experiment with Under Sampling:

# %%
# %%time 
#Initiate the output metrics matrix
outputmetrics = pd.DataFrame(index=['F1 Macro on Train','F1 Macro on Test'], columns=classcolumns)

rus = RandomUnderSampler(random_state=42)

#Loop through different classes to train XGBOOST models and get F1 Macro Scores
for col in classcolumns:  
    y_train, y_test = df.loc[X_train.index, col], df.loc[X_test.index, col] #get the y labels with same index as trainning set while loop through the list of classes

    X_res, y_res = rus.fit_resample(X_train, y_train) # Using SMOTE to process the imbalance between classes.
    X_res = pd.DataFrame(X_res, columns=normcolumns)
    
    f1mtrain, f1mtest = xgboostrun(X_res, X_test, y_res, y_test,0)
    outputmetrics.loc['F1 Macro on Train'][col] = f1mtrain*100
    outputmetrics.loc['F1 Macro on Test'][col] = f1mtest*100
# Out:
# CPU times: user 10.9 s, sys: 80 ms, total: 11 s
# Wall time: 11 s

# %%
print('The output with class imbalanced process')
outputmetrics
# Out:
# The output with class imbalanced process
#                     Check1   Check2   Check3   Check4   Check5   Check6  \
# F1 Macro on Train  33.3333  33.3333  33.3333  33.3333  33.3333  33.3333
# F1 Macro on Test   49.8329  49.1428   49.225  47.4306  49.7052  42.0155
#
#                     Check7   Check8
# F1 Macro on Train  33.3333  33.3333
# F1 Macro on Test   49.2319  49.7505

# %% [markdown]
# ## Experiment with Over Sampling SMOTE technique:

# %%
# %%time 
#Initiate the output metrics matrix
outputmetrics = pd.DataFrame(index=['F1 Macro on Train','F1 Macro on Test'], columns=classcolumns)

sm = SMOTE(random_state=42) #initial the SMOTE

#Loop through different classes to train XGBOOST models and get F1 Macro Scores
for col in classcolumns:  
    y_train, y_test = df.loc[X_train.index, col], df.loc[X_test.index, col] #get the y labels with same index as trainning set while loop through the list of classes

    X_res, y_res = sm.fit_resample(X_train, y_train) # Using SMOTE to process the imbalance between classes.
    X_res = pd.DataFrame(X_res, columns=normcolumns)
    
    f1mtrain, f1mtest = xgboostrun(X_res, X_test, y_res, y_test,0)
    outputmetrics.loc['F1 Macro on Train'][col] = f1mtrain*100
    outputmetrics.loc['F1 Macro on Test'][col] = f1mtest*100
# Out:
# CPU times: user 2min 55s, sys: 323 ms, total: 2min 55s
# Wall time: 2min 55s

# %%
print('The output with class imbalanced process')
outputmetrics
# Out:
# The output with class imbalanced process
#                     Check1   Check2   Check3   Check4   Check5   Check6  \
# F1 Macro on Train  33.3333  33.3333  33.3333  33.3333  33.3333  33.3333
# F1 Macro on Test   49.8329  49.1428   49.225  47.4306  49.7052  42.0155
#
#                     Check7   Check8
# F1 Macro on Train  33.3333  33.3333
# F1 Macro on Test   49.2319  49.7505

# %% [markdown]
# ## Experiment with Scaled pos weight class imbalanced technique:

# %%
# %%time 
#Not process the imbalanced classes issue
#Initiate the output metrics matrix
outputmetrics = pd.DataFrame(index=['F1 Macro on Train','F1 Macro on Test'], columns=classcolumns)


#Loop through different classes to train XGBOOST models and get F1 Macro Scores
for col in classcolumns:
    y_train, y_test = df.loc[X_train.index, col], df.loc[X_test.index, col] #get the y labels with same index as trainning set while loop through the list of classes
    weight = (len(y_train)-y_train.sum())/ y_train.sum()
    f1mtrain, f1mtest = xgboostrun(X_train, X_test, y_train, y_test, weight)
    outputmetrics.loc['F1 Macro on Train'][col] = f1mtrain*100
    outputmetrics.loc['F1 Macro on Test'][col] = f1mtest*100
# Out:
# CPU times: user 3min 45s, sys: 310 ms, total: 3min 45s
# Wall time: 3min 45s

# %%
print('The output with class imbalanced process')
outputmetrics
# Out:
# The output with class imbalanced process
#                     Check1   Check2   Check3   Check4   Check5   Check6  \
# F1 Macro on Train  99.5779  99.6855  98.9547  99.5694  99.2541  99.6331
# F1 Macro on Test   99.5246  99.4421   98.711  99.4535  99.1597  99.5813
#
#                     Check7 Check8
# F1 Macro on Train  77.0178    100
# F1 Macro on Test   76.8437    100

# %% [markdown]
# ## Experiment with Over Sampling and Scaled pos weight class technique in one:

# %%
# %%time 
#Initiate the output metrics matrix
outputmetrics = pd.DataFrame(index=['F1 Macro on Train','F1 Macro on Test'], columns=classcolumns)


sm = SMOTE(random_state=42) #initial the SMOTE
#rus = RandomUnderSampler(random_state=42)

#Loop through different classes to train XGBOOST models and get F1 Macro Scores
for col in classcolumns:  
    y_train, y_test = df.loc[X_train.index, col], df.loc[X_test.index, col] #get the y labels with same index as trainning set

    X_res, y_res = sm.fit_resample(X_train, y_train) # Using SMOTE to process the imbalance between classes.
    X_res = pd.DataFrame(X_res, columns=normcolumns)
    
    weight = (len(y_res)-y_res.sum())/ y_res.sum()

    f1mtrain, f1mtest = xgboostrun(X_res, X_test, y_res, y_test,weight)
    outputmetrics.loc['F1 Macro on Train'][col] = f1mtrain*100
    outputmetrics.loc['F1 Macro on Test'][col] = f1mtest*100
# Out:
# CPU times: user 9min 18s, sys: 640 ms, total: 9min 18s
# Wall time: 9min 18s

# %%
print('The output with both scale pos weight and SMOTE oversampling imbalanced class process')
outputmetrics
# Out:
# The output with class imbalanced process
#                     Check1   Check2   Check3   Check4   Check5   Check6  \
# F1 Macro on Train  99.9951  99.9866  99.9492  99.9478   99.952  99.6727
# F1 Macro on Test   99.5236  99.4199   98.923  99.5592  98.4287  99.5598
#
#                     Check7 Check8
# F1 Macro on Train   98.339    100
# F1 Macro on Test   83.0683    100

# %% [markdown]
# ## Outcomes of XGBOOST
# <div class="alert alert-info">
# In conclusion, When apply both Over Sampling and Scaled pos weight technique at the same time, our F1 accuracies have improved significantly in all classes.
# </div>

# %% [markdown]
# # Experiment with ruleset

# %%
def BRuleSet(X_train, X_test, y_train, y_test, max_rules=10, max_iter=3):
    model = ()
    model = rs.BayesianRuleSet(method='forest', max_rules=max_rules, max_iter=max_iter)

    model.fit(X_train, y_train)
    
    #scoring on train set
    y_pred = model.predict(X_train) #export class
    f1mtrain = f1_score(y_train, y_pred, average='macro')
    
    # scoring on test set
    y_pred = model.predict(X_test) #export class
    f1mtest = f1_score(y_test, y_pred, average='macro')
    
    return model, f1mtrain, f1mtest;

# %% [markdown]
# ## Ruleset with undersampling imbalance process:

# %% [markdown]
# ### First run to get the initial results:

# %%
# %%time 
#Initiate the output metrics matrix
outputmetrics = pd.DataFrame(index=['F1 Macro on Train','F1 Macro on Test'], columns=classcolumns)

rus = RandomUnderSampler(random_state=42) #undersampling 

#Loop through different classes to train XGBOOST models and get F1 Macro Scores
for col in classcolumns:
    print("\n","Rules for Anomaly Detection on",col,":")
    
    #get the y labels with same index as X_train set while loop through the list of classes:
    y_train, y_test = df.loc[X_train.index, col].as_matrix(), df.loc[X_test.index, col].as_matrix() 

    XX_train, yy_train = rus.fit_resample(X_train, y_train) # Using undersampling technique to process the imbalance between classes.
    XX_train = pd.DataFrame(XX_train, columns=normcolumns)
    
    modeloutput, f1mtrain, f1mtest = BRuleSet(XX_train, X_test, yy_train, y_test, max_rules=10, max_iter=3)
    outputmetrics.loc['F1 Macro on Train'][col] = f1mtrain*100
    outputmetrics.loc['F1 Macro on Test'][col] = f1mtest*100
    print("="*50)
# Out:
#  Rules for Anomaly Detection on Check1 :
#
# ** chain = 1, max at iter = 0 **
#  accuracy = 0.9878731343283582, TP = 1046,FP = 0, TN = 1072, FN = 26
#  old is -999999999.9, pt_new is -144.95355325570972, prior_ChsRules=-17.28969830754795, likelihood_1 = -2.438862711286447, likelihood_2 = -125.22499223687532
#
# ['90.01<=CPU', '37.57<=PhysMEM', 'BlockingPhaseSec<784544.0', '2.0<=BlockingPhaseSec', 'PhysMEM<99.36']
# [7]
#
# ** chain = 1, max at iter = 1 **
#  accuracy = 0.9976679104477612, TP = 1067,FP = 0, TN = 1072, FN = 5
#  old is -144.85355325570973, pt_new is -69.33233906310261, prior_ChsRules=-33.856399064097786, likelihood_1 = -2.4570214462999047, likelihood_2 = -33.01891855270492
#
# ['90.01<=CPU', '37.57<=PhysMEM', 'BlockingPhaseSec<784544.0', '2.0<=BlockingPhaseSec', 'PhysMEM<99.36']
# ['90.01<=CPU', '0.05<=TablesAllocation', 'TablesAllocation<67.37', '-417.0<=LogSegmentChange', 'LogSegmentChange<907.0']
# [7, 4]
# ...
#
#  Rules for Anomaly Detection on Check2 :
#
# ...

# %%
print('F1 Macro metric output of ruleset CHeckwhen apply undersampling imbalance process techniques:')
outputmetrics
# Out:
# F1 Macro metric output of ruleset when apply undersampling imbalance process techniques:
#                     Check1   Check2   Check3   Check4   Check5   Check6  \
# F1 Macro on Train  99.7668  89.6861  94.1312  99.8282  98.2815  94.9605
# F1 Macro on Test   99.4645  94.0131  95.4648  99.3387  97.8837  96.1615
#
#                     Check7   Check8
# F1 Macro on Train  81.9862  72.6436
# F1 Macro on Test   69.2734   66.326

# %% [markdown]
# ### Improve the outcome in each class by increase the number of interation and rules:

# %% [markdown]
# #### Running on class Check1

# %%
# %%time 
#Initiate the output metrics matrix

rus = RandomUnderSampler(random_state=42)

print("\n","Rules for Anomaly Detection on Check1:")
  
#get the y labels with same index as X_train set
y_train, y_test = df.loc[X_train.index, 'Check1'].as_matrix(), df.loc[X_test.index, 'Check1'].as_matrix() 

XX_train, yy_train = rus.fit_resample(X_train, y_train) # Using undersampling technique to process the imbalance between classes.
XX_train = pd.DataFrame(XX_train, columns=normcolumns)
   
modeloutput, f1mtrain, f1mtest = BRuleSet(XX_train, X_test, yy_train, y_test, max_rules=10, max_iter=10)
print("="*50)
# print("Best Rules")
# for x in modeloutput.rule_explainations:
#   print(modeloutput.rule_explainations[x][0]) 
print("F1 Macro Score on Train set", f1mtrain*100)
print("F1 Macro Score on Test set", f1mtest*100)
print("="*50)
# Out:
#  Rules for Anomaly Detection on Check1:
#
# ** chain = 1, max at iter = 0 **
#  accuracy = 0.9990697674418605, TP = 1073,FP = 0, TN = 1075, FN = 2
#  old is -999999999.9, pt_new is -35.66315226596316, prior_ChsRules=-17.28969830754795, likelihood_1 = -2.4621496626657517, likelihood_2 = -15.91130429574946
#
# ['90.01<=CPU', '11.0<=DiagnosisFiles', 'DiagnosisFiles<26887.0', '0.0<=HighPriorityAlerts']
# [8]
# ...
# F1 Macro Score on Train set 99.90697666368993
# F1 Macro Score on Test set 99.40786490938083
# ...
# CPU times: user 6 s, sys: 128 ms, total: 6.12 s
# Wall time: 6.12 s

# %% [markdown]
# <div class="alert alert-info">
# We do not have any improvement compared with the previous one, so we stop
# </div>

# %% [markdown]
# #### Running on class Check2

# %%
# %%time 
#Initiate the output metrics matrix

rus = RandomUnderSampler(random_state=42)

print("\n","Rules for Anomaly Detection on Check2:")
  
#get the y labels with same index as X_train set
y_train, y_test = df.loc[X_train.index, 'Check2'].as_matrix(), df.loc[X_test.index, 'Check2'].as_matrix() 

XX_train, yy_train = rus.fit_resample(X_train, y_train) # Using undersampling technique to process the imbalance between classes.
XX_train = pd.DataFrame(XX_train, columns=normcolumns)
   
modeloutput, f1mtrain, f1mtest = BRuleSet(XX_train, X_test, yy_train, y_test, max_rules=10, max_iter=10)
print("="*50)
print("F1 Macro Score on Train set", f1mtrain*100)
print("F1 Macro Score on Test set", f1mtest*100)
print("="*50)
# Out:
#  Rules for Anomaly Detection on Check2:
#
# ** chain = 1, max at iter = 0 **
#  accuracy = 0.8584938400138816, TP = 4137,FP = 5, TN = 5758, FN = 1626
#  old is -999999999.9, pt_new is -3974.8817297986516, prior_ChsRules=-17.28969830754795, likelihood_1 = -40.720541284858655, likelihood_2 = -3916.8714902062447
#
# ['InstanceMEM<93.2', '90.0<=InstanceMEM', '11.0<=DiagnosisFiles', 'LogSegmentChange<1710.0', '-2221.0<=LogSegmentChange']
# [0]
# ...
# F1 Macro Score on Train set 85.56384842126312
# F1 Macro Score on Test set 91.71064336658783
# ...
# CPU times: user 4min 7s, sys: 9min 4s, total: 13min 11s
# Wall time: 13min 11s

# %%
# %%time 
#Initiate the output metrics matrix

rus = RandomUnderSampler(random_state=42)

print("\n","Rules for Anomaly Detection on Check2:")
  
#get the y labels with same index as X_train set
y_train, y_test = df.loc[X_train.index, 'Check2'].as_matrix(), df.loc[X_test.index, 'Check2'].as_matrix() 

XX_train, yy_train = rus.fit_resample(X_train, y_train) # Using undersampling technique to process the imbalance between classes.
XX_train = pd.DataFrame(XX_train, columns=normcolumns)
   
modeloutput, f1mtrain, f1mtest = BRuleSet(XX_train, X_test, yy_train, y_test, max_rules=10, max_iter=20)
print("="*50)
print("F1 Macro Score on Train set", f1mtrain*100)
print("F1 Macro Score on Test set", f1mtest*100)
print("="*50)
# Out:
#  Rules for Anomaly Detection on Check2:
#
# ** chain = 1, max at iter = 0 **
#  accuracy = 0.853461738677772, TP = 4076,FP = 2, TN = 5761, FN = 1687
#  old is -999999999.9, pt_new is -4046.8631363043733, prior_ChsRules=-17.28969830754795, likelihood_1 = -19.71372826963011, likelihood_2 = -4009.859709727195
#
# ['90.0<=InstanceMEM', '73.19<=IndexServerAllocationLimit', 'PhysMEM<99.33', 'IndexServerAllocationLimit<99.24', 'InstanceMEM<93.2', '7.38<=PhysMEM']
# [4]
#
# ** chain = 1, max at iter = 1 **
#  accuracy = 0.8588408814853375, TP = 4139,FP = 3, TN = 5760, FN = 1624
#  old is -4046.7631363043733, pt_new is -3972.1642874785193, prior_ChsRules=-30.844137565378333, likelihood_1 = -27.012816068955317, likelihood_2 = -3914.3073338441855
#
# ['90.0<=InstanceMEM', '73.19<=IndexServerAllocationLimit', 'PhysMEM<99.33', 'IndexServerAllocationLimit<99.24', 'InstanceMEM<93.2', '7.38<=PhysMEM']
# ['90.0<=InstanceMEM', 'HighPriorityAlerts<10.0', 'InstanceMEM<93.2', '0.0<=HighPriorityAlerts']
# ...

# %% [markdown]
# <div class="alert alert-info">
# We do not have any improvement compared with the previous one, so we stop.
# </div>

# %% [markdown]
# #### Running on class Check3

# %%
# %%time 
#Initiate the output metrics matrix

rus = RandomUnderSampler(random_state=42)

print("\n","Rules for Anomaly Detection on Check3:")
  
#get the y labels with same index as X_train set
y_train, y_test = df.loc[X_train.index, 'Check3'].as_matrix(), df.loc[X_test.index, 'Check3'].as_matrix() 

XX_train, yy_train = rus.fit_resample(X_train, y_train) # Using undersampling technique to process the imbalance between classes.
XX_train = pd.DataFrame(XX_train, columns=normcolumns)
   
modeloutput, f1mtrain, f1mtest = BRuleSet(XX_train, X_test, yy_train, y_test, max_rules=10, max_iter=10)
print("="*50)
print("F1 Macro Score on Train set", f1mtrain*100)
print("F1 Macro Score on Test set", f1mtest*100)
print("="*50)
# Out:
#  Rules for Anomaly Detection on Check3:
#
# ** chain = 1, max at iter = 0 **
#  accuracy = 0.9920091324200914, TP = 5180,FP = 8, TN = 5248, FN = 76
#  old is -999999999.9, pt_new is -479.95489781448623, prior_ChsRules=-17.28969830754795, likelihood_1 = -61.94217382758029, likelihood_2 = -400.723025679358
#
# ['95.0<=PhysMEM', '34827429.0<=DiagnosisFilesSize', 'PhysMEM<98.99', '0.0<=BlockingPhaseSec']
# [7]
# ...
# F1 Macro Score on Train set 99.20087980255123
# F1 Macro Score on Test set 98.19065856368
# ...
# CPU times: user 9min 29s, sys: 25min 22s, total: 34min 52s
# Wall time: 34min 52s

# %% [markdown]
# <div class="alert alert-info">
# We do not have any improvement compared with the previous one, so we stop.
# </div>

# %% [markdown]
# #### Running on class Check4

# %%
# %%time 
#Initiate the output metrics matrix

rus = RandomUnderSampler(random_state=42)

print("\n","Rules for Anomaly Detection on Check4:")
  
#get the y labels with same index as X_train set
y_train, y_test = df.loc[X_train.index, 'Check4'].as_matrix(), df.loc[X_test.index, 'Check4'].as_matrix() 

XX_train, yy_train = rus.fit_resample(X_train, y_train) # Using undersampling technique to process the imbalance between classes.
XX_train = pd.DataFrame(XX_train, columns=normcolumns)
   
modeloutput, f1mtrain, f1mtest = BRuleSet(XX_train, X_test, yy_train, y_test, max_rules=10, max_iter=10)
print("="*50)
print("F1 Macro Score on Train set", f1mtrain*100)
print("F1 Macro Score on Train set", f1mtest*100)
print("="*50)
# Out:
#  Rules for Anomaly Detection on Check4:
#
# ** chain = 1, max at iter = 0 **
#  accuracy = 0.5, TP = 0,FP = 0, TN = 16359, FN = 16359
#  old is -999999999.9, pt_new is -22747.259963208006, prior_ChsRules=-0.029850249324226752, likelihood_1 = 0.0, likelihood_2 = -22747.23011295868
#
# []
#
# ** chain = 1, max at iter = 1 **
#  accuracy = 0.9952319823950119, TP = 16244,FP = 41, TN = 16318, FN = 115
#  old is -22747.159963208007, pt_new is -993.9231417802416, prior_ChsRules=-17.28969830754795, likelihood_1 = -288.8811311169509, likelihood_2 = -687.7523123557428
#
# ['90.0<=IndexServerAllocationLimit', '11936393.0<=DiagnosisFilesSize', 'IndexServerAllocationLimit<99.05', '0.0<=MinDailyNumberOfSuccessfulLogBackups', 'MinDailyNumberOfSuccessfulLogBackups<1026.0']
# [4]
#
# ** chain = 1, max at iter = 2 **
#  accuracy = 0.9981967112904212, TP = 16341,FP = 41, TN = 16318, FN = 18
# ...

# %% [markdown]
# <div class="alert alert-info">
# We do not have any improvement compared with the previous one, so we stop.
# </div>

# %% [markdown]
# #### Running on class Check5

# %%
# %%time 
#Initiate the output metrics matrix

rus = RandomUnderSampler(random_state=42)

print("\n","Rules for Anomaly Detection on Check5:")
  
#get the y labels with same index as X_train set
y_train, y_test = df.loc[X_train.index, 'Check5'].as_matrix(), df.loc[X_test.index, 'Check5'].as_matrix() 

XX_train, yy_train = rus.fit_resample(X_train, y_train) # Using undersampling technique to process the imbalance between classes.
XX_train = pd.DataFrame(XX_train, columns=normcolumns)
   
modeloutput, f1mtrain, f1mtest = BRuleSet(XX_train, X_test, yy_train, y_test, max_rules=10, max_iter=10)
print("="*50)
print("F1 Macro Score on Train set", f1mtrain*100)
print("F1 Macro Score on Test set", f1mtest*100)
print("="*50)
# Out:
#  Rules for Anomaly Detection on Check5:
#
# ** chain = 1, max at iter = 0 **
#  accuracy = 0.5, TP = 0,FP = 0, TN = 2032, FN = 2032
#  old is -999999999.9, pt_new is -2883.7607929779615, prior_ChsRules=-0.02985016693128273, likelihood_1 = 0.0, likelihood_2 = -2883.73094281103
#
# []
#
# ** chain = 1, max at iter = 5 **
#  accuracy = 0.9827755905511811, TP = 1962,FP = 0, TN = 2032, FN = 70
#  old is -2883.6607929779616, pt_new is -327.01607182042017, prior_ChsRules=-13.679170357703697, likelihood_1 = -3.0262614785885944, likelihood_2 = -310.3106399841279
#
# ['70.01<=TablesAllocation', 'IndexServerAllocationLimit<98.61']
# [5]
# ...
# F1 Macro Score on Train set 98.27704788920198
# F1 Macro Score on Test set 97.57977978435312
# ...
# CPU times: user 7.28 s, sys: 140 ms, total: 7.42 s
# Wall time: 7.42 s

# %% [markdown]
# <div class="alert alert-info">
# We do not have any improvement compared with the previous one, so we stop.
# </div>

# %% [markdown]
# #### Running on class Check6

# %%
# %%time 
#Initiate the output metrics matrix

rus = RandomUnderSampler(random_state=42)

print("\n","Rules for Anomaly Detection on Check6:")
  
#get the y labels with same index as X_train set
y_train, y_test = df.loc[X_train.index, 'Check6'].as_matrix(), df.loc[X_test.index, 'Check6'].as_matrix() 

XX_train, yy_train = rus.fit_resample(X_train, y_train) # Using undersampling technique to process the imbalance between classes.
XX_train = pd.DataFrame(XX_train, columns=normcolumns)
   
modeloutput, f1mtrain, f1mtest = BRuleSet(XX_train, X_test, yy_train, y_test, max_rules=10, max_iter=10)
print("="*50)
print("F1 Macro Score on Train set", f1mtrain*100)
print("F1 Macro Score on Train set", f1mtest*100)
print("="*50)
# Out:
#  Rules for Anomaly Detection on Check6:
#
# ** chain = 1, max at iter = 0 **
#  accuracy = 0.97968434454298, TP = 43706,FP = 1, TN = 45555, FN = 1850
#  old is -999999999.9, pt_new is -7853.425324939051, prior_ChsRules=-17.24051456998859, likelihood_1 = -16.769904788273152, likelihood_2 = -7819.414905580789
#
# ['151.0<=DiagnosisFiles', '0.0<=BlockingPhaseSec', '0.0<=HighPriorityAlerts', 'HighPriorityAlerts<21.0', 'BlockingPhaseSec<9116534.0']
# [4]
# ...
# F1 Macro Score on Train set 97.96759744092748
# F1 Macro Score on Train set 98.59279920931188
# ...
# CPU times: user 14min 57s, sys: 36min 14s, total: 51min 11s
# Wall time: 51min 12s

# %%
# %%time 
#Initiate the output metrics matrix

rus = RandomUnderSampler(random_state=42)

print("\n","Rules for Anomaly Detection on Check6:")
  
#get the y labels with same index as X_train set
y_train, y_test = df.loc[X_train.index, 'Check6'].as_matrix(), df.loc[X_test.index, 'Check6'].as_matrix() 

XX_train, yy_train = rus.fit_resample(X_train, y_train) # Using undersampling technique to process the imbalance between classes.
XX_train = pd.DataFrame(XX_train, columns=normcolumns)
   
modeloutput, f1mtrain, f1mtest = BRuleSet(XX_train, X_test, yy_train, y_test, max_rules=10, max_iter=20)
print("="*50)
print("F1 Macro Score on Train set", f1mtrain*100)
print("F1 Macro Score on Test set", f1mtest*100)
print("="*50)
# Out:
#  Rules for Anomaly Detection on Check6:
#
# ** chain = 1, max at iter = 0 **
#  accuracy = 0.5, TP = 0,FP = 0, TN = 45556, FN = 45556
#  old is -999999999.9, pt_new is -63223.503121872774, prior_ChsRules=-0.02985023807559628, likelihood_1 = 0.0, likelihood_2 = -63223.4732716347
#
# []
#
# ** chain = 1, max at iter = 5 **
#  accuracy = 0.9796953200456581, TP = 43707,FP = 1, TN = 45555, FN = 1849
#  old is -63223.403121872776, pt_new is -7846.49084185824, prior_ChsRules=-13.55163516390894, likelihood_1 = -16.769950443102744, likelihood_2 = -7816.169256251228
#
# ['151.0<=DiagnosisFiles', '0.0<=TablesAllocation', 'TablesAllocation<92.87']
# [2]
# ...
# F1 Macro Score on Train set 97.96869634839771
# F1 Macro Score on Train set 98.60366552772695
# ...
# CPU times: user 15min 46s, sys: 38min 38s, total: 54min 25s
# Wall time: 54min 25s

# %% [markdown]
# <div class="alert alert-info">
# We do not have any improvement compared with the previous one, so we stop.
# </div>

# %% [markdown]
# #### Running on class Check7

# %%
# %%time 
#Initiate the output metrics matrix

rus = RandomUnderSampler(random_state=42)

print("\n","Rules for Anomaly Detection on Check7:")
  
#get the y labels with same index as X_train set
y_train, y_test = df.loc[X_train.index, 'Check7'].as_matrix(), df.loc[X_test.index, 'Check7'].as_matrix() 

XX_train, yy_train = rus.fit_resample(X_train, y_train) # Using undersampling technique to process the imbalance between classes.
XX_train = pd.DataFrame(XX_train, columns=normcolumns)
   
modeloutput, f1mtrain, f1mtest = BRuleSet(XX_train, X_test, yy_train, y_test, max_rules=10, max_iter=10)
print("="*50)
print("F1 Macro Score on Train set", f1mtrain*100)
print("F1 Macro Score on Train set", f1mtest*100)
print("="*50)
# Out:
#  Rules for Anomaly Detection on Check7:
#
# ** chain = 1, max at iter = 0 **
#  accuracy = 0.5, TP = 0,FP = 0, TN = 5068, FN = 5068
#  old is -999999999.9, pt_new is -7093.698380171535, prior_ChsRules=-0.02985008501855191, likelihood_1 = 0.0, likelihood_2 = -7093.6685300865165
#
# []
#
# ** chain = 1, max at iter = 6 **
#  accuracy = 0.824585635359116, TP = 3562,FP = 272, TN = 4796, FN = 1506
#  old is -7093.598380171535, pt_new is -4498.230485208698, prior_ChsRules=-17.338088412521756, likelihood_1 = -988.9644886882513, likelihood_2 = -3491.927908107925
#
# ['1.0<=LogSegmentChange', 'DiagnosisFilesSize<199000000000.0', '6243751.0<=DiagnosisFilesSize', '0.73<=Disk']
# [6]
# ...
# F1 Macro Score on Train set 82.19465865684526
# F1 Macro Score on Train set 68.93858911446173
# ...
# CPU times: user 8min 37s, sys: 26min 50s, total: 35min 27s
# Wall time: 35min 27s

# %%
# %%time 
#Initiate the output metrics matrix

rus = RandomUnderSampler(random_state=42)

print("\n","Rules for Anomaly Detection on Check7:")
  
#get the y labels with same index as X_train set
y_train, y_test = df.loc[X_train.index, 'Check7'].as_matrix(), df.loc[X_test.index, 'Check7'].as_matrix() 

XX_train, yy_train = rus.fit_resample(X_train, y_train) # Using undersampling technique to process the imbalance between classes.
XX_train = pd.DataFrame(XX_train, columns=normcolumns)
   
modeloutput, f1mtrain, f1mtest = BRuleSet(XX_train, X_test, yy_train, y_test, max_rules=10, max_iter=20)
print("="*50)
print("F1 Macro Score on Train set", f1mtrain*100)
print("F1 Macro Score on Test set", f1mtest*100)
print("="*50)
# Out:
#  Rules for Anomaly Detection on Check7:
#
# ** chain = 1, max at iter = 0 **
#  accuracy = 0.5, TP = 0,FP = 0, TN = 5034, FN = 5034
#  old is -999999999.9, pt_new is -7046.557837492796, prior_ChsRules=-0.02985008501855191, likelihood_1 = 0.0, likelihood_2 = -7046.527987407778
#
# []
#
# ** chain = 1, max at iter = 1 **
#  accuracy = 0.826082638061184, TP = 3549,FP = 266, TN = 4768, FN = 1485
#  old is -7046.457837492796, pt_new is -4443.2939437170735, prior_ChsRules=-17.338088412521756, likelihood_1 = -971.9665471051037, likelihood_2 = -3453.989308199448
#
# ['1.0<=LogSegmentChange', '0.0<=MaxDailyNumberOfFailedLogBackups', 'DiagnosisFiles<10390.0', '6.0<=DiagnosisFiles']
# [0]
# ...
# F1 Macro Score on Train set 82.34951543153916
# F1 Macro Score on Test set 68.9382755651932
# ...
# CPU times: user 1min 33s, sys: 2min 44s, total: 4min 17s
# Wall time: 4min 17s

# %%
# %%time 
#Initiate the output metrics matrix

rus = RandomUnderSampler(random_state=42)

print("\n","Rules for Anomaly Detection on Check7:")
  
#get the y labels with same index as X_train set
y_train, y_test = df.loc[X_train.index, 'Check7'].as_matrix(), df.loc[X_test.index, 'Check7'].as_matrix() 

XX_train, yy_train = rus.fit_resample(X_train, y_train) # Using undersampling technique to process the imbalance between classes.
XX_train = pd.DataFrame(XX_train, columns=normcolumns)
   
modeloutput, f1mtrain, f1mtest = BRuleSet(XX_train, X_test, yy_train, y_test, max_rules=20, max_iter=30)
print("="*50)
print("F1 Macro Score on Train set", f1mtrain*100)
print("F1 Macro Score on Test set", f1mtest*100)
print("="*50)
# Out:
#  Rules for Anomaly Detection on Check7:
#
# ** chain = 1, max at iter = 0 **
#  accuracy = 0.5, TP = 0,FP = 0, TN = 4941, FN = 4941
#  old is -999999999.9, pt_new is -6917.6142504076515, prior_ChsRules=-0.02985008501855191, likelihood_1 = 0.0, likelihood_2 = -6917.584400322633
#
# []
#
# ** chain = 1, max at iter = 9 **
#  accuracy = 0.7679619510220603, TP = 2883,FP = 235, TN = 4706, FN = 2058
#  old is -6917.514250407651, pt_new is -5049.575692351022, prior_ChsRules=-17.338088412521756, likelihood_1 = -840.9653579619905, likelihood_2 = -4191.272245976509
#
# ['1.0<=LogSegmentChange', '0.0<=BlockingPhaseSec', 'CPU<33.03', '0.2<=CPU']
# [18]
#
# ** chain = 1, max at iter = 13 **
#  accuracy = 0.8085407812183768, TP = 3309,FP = 260, TN = 4681, FN = 1632
#  old is -5049.475692351021, pt_new is -4609.493814238516, prior_ChsRules=-33.95317943835107, likelihood_1 = -938.6462977459876, likelihood_2 = -3636.8943370541774
#
# ...

# %% [markdown]
# <div class="alert alert-info">
# We do not have any improvement compared with the previous one, so we stop.
# </div>

# %% [markdown]
# #### Running on class Check8

# %%
# %%time 
#Initiate the output metrics matrix

rus = RandomUnderSampler(random_state=42)

print("\n","Rules for Anomaly Detection on Check8:")
  
#get the y labels with same index as X_train set
y_train, y_test = df.loc[X_train.index, 'Check8'].as_matrix(), df.loc[X_test.index, 'Check8'].as_matrix() 

XX_train, yy_train = rus.fit_resample(X_train, y_train) # Using undersampling technique to process the imbalance between classes.
XX_train = pd.DataFrame(XX_train, columns=normcolumns)
   
modeloutput, f1mtrain, f1mtest = BRuleSet(XX_train, X_test, yy_train, y_test, max_rules=10, max_iter=10)
print("="*50)
print("F1 Macro Score on Train set", f1mtrain*100)
print("F1 Macro Score on Test set", f1mtest*100)
print("="*50)
# Out:
#  Rules for Anomaly Detection on Check8:
#
# ** chain = 1, max at iter = 0 **
#  accuracy = 0.8871268656716418, TP = 1277,FP = 32, TN = 1576, FN = 331
#  old is -999999999.9, pt_new is -1067.9190701277253, prior_ChsRules=-17.47874491949915, likelihood_1 = -152.73019350466052, likelihood_2 = -897.7101317035656
#
# ['1.0<=IndexServerRestarts', '0.0<=Dumps', 'InstanceMEM<97.15', '1.38<=InstanceMEM']
# [5]
#
# ** chain = 1, max at iter = 1 **
#  accuracy = 0.9856965174129353, TP = 1604,FP = 42, TN = 1566, FN = 4
#  old is -1067.8190701277254, pt_new is -261.64824539939355, prior_ChsRules=-34.23449247618555, likelihood_1 = -198.10007582207322, likelihood_2 = -29.313677101134772
#
# ['1.0<=IndexServerRestarts', '0.0<=Dumps', 'InstanceMEM<97.15', '1.38<=InstanceMEM']
# ['1.0<=NameServerRestarts', 'DiagnosisFilesSize<199000000000.0', '17732732.0<=DiagnosisFilesSize', '7.0<=DiagnosisFiles', 'DiagnosisFiles<4929.0']
# [5, 4]
# ...
# F1 Macro Score on Train set 98.56945201394188
# ...

# %%
# %%time 
#Initiate the output metrics matrix

rus = RandomUnderSampler(random_state=42)

print("\n","Rules for Anomaly Detection on Check8:")
  
#get the y labels with same index as X_train set
y_train, y_test = df.loc[X_train.index, 'Check8'].as_matrix(), df.loc[X_test.index, 'Check8'].as_matrix() 

XX_train, yy_train = rus.fit_resample(X_train, y_train) # Using undersampling technique to process the imbalance between classes.
XX_train = pd.DataFrame(XX_train, columns=normcolumns)
   
modeloutput, f1mtrain, f1mtest = BRuleSet(XX_train, X_test, yy_train, y_test, max_rules=20, max_iter=20)
print("="*50)
print("F1 Macro Score on Train set", f1mtrain*100)
print("F1 Macro Score on Test set", f1mtest*100)
print("="*50)
# Out:
#  Rules for Anomaly Detection on Check8:
#
# ** chain = 1, max at iter = 0 **
#  accuracy = 0.8815298507462687, TP = 1259,FP = 32, TN = 1576, FN = 349
#  old is -999999999.9, pt_new is -1095.7396238251017, prior_ChsRules=-13.70982264270424, likelihood_1 = -152.30097638438087, likelihood_2 = -929.7288247980166
#
# ['1.0<=IndexServerRestarts', 'IndexServerAllocationLimit<98.4', '0.74<=IndexServerAllocationLimit']
# [1]
#
# ** chain = 1, max at iter = 1 **
#  accuracy = 0.9695273631840796, TP = 1552,FP = 42, TN = 1566, FN = 56
#  old is -1095.6396238251018, pt_new is -474.76822523473265, prior_ChsRules=-31.15871750106453, likelihood_1 = -196.78383454567916, likelihood_2 = -246.82567318798897
#
# ['1.0<=IndexServerRestarts', 'IndexServerAllocationLimit<98.4', '0.74<=IndexServerAllocationLimit']
# ['1.0<=NameServerRestarts', 'DeltaSize<54224825156.0', '28308291.0<=DeltaSize', 'ColumnUnloads<286060.0', '0.0<=ColumnUnloads']
# [1, 19]
#
# ** chain = 1, max at iter = 4 **
# ...

# %% [markdown]
# <div class="alert alert-info">
# We do not have any improvement compared with the previous one, so we stop.
# </div>

# %% [markdown]
# ## Outcomes with Ruleset:

# %% [markdown]
# | Tunning with Ruleset  | Check1 | Check2 | Check3 | Check4 | Check5 | Check6 | Check7 | Check8 |
# |-----------------------|--------|--------|--------|--------|--------|--------|--------|--------|
# | F1 Macro on Train     | 99.907 | 89.686 | 94.131 | 99.820 | 98.282 | 97.969 | 82.360 | 98.66  |
# | F1 Macro on Test      | 99.408 | 94.013 | 95.465 | 99.373 | 97.884 | 98.604 | 69.293 | 71.845 |
#
# **Rules on each class:**
#
# | Rules           | Check1                      | Check2                                  | Check3                                           | Check4                                           |
# |-----------------|-----------------------------|-----------------------------------------|--------------------------------------------------|--------------------------------------------------|
# |01               | 90.01<= **CPU**                 | 11.0<=**DiagnosisFiles**                    | 38332780.0<=**DiagnosisFilesSize**                   | 11.0<=**DiagnosisFiles**<301176.0                    |
# |02               | 11.0<**DiagnosisFiles**<26887.0 | 0.0<=**HighPriorityAlerts**<12.0            | 33.5<=**InstanceMEM**<95.43                          | 11936393.0<=**DiagnosisFilesSize**                   |
# |03               | 0.0<=**HighPriorityAlerts**     | 73.19<=**IndexServerAllocationLimit**<98.74 | -994.0<=**LogSegmentChange**                         | 0.0<=**HighPriorityAlerts**<21.0                     |
# |04               | None                        | 90.0<=**InstanceMEM**<93.52                 | 0.0<=**MinDailyNumberOfSuccessfulLogBackups**<1643.0 | 90.0<=**IndexServerAllocationLimit**<99.05           |
# |05               | None                        | 20.47<=**TablesAllocation**<79.26           | 95.0<=**PhysMEM**<97.59                              | 0.0<=**MinDailyNumberOfSuccessfulLogBackups**<1026.0 |
#
# | Rules           | Check5                  | Check6                                | Check7                                | Check8                      |
# |-----------------|-------------------------|---------------------------------------|---------------------------------------|-----------------------------|
# |01               | 0.0<=**HighPriorityAlerts** | 151.0<=**DiagnosisFiles**                 | 0.0<=**BlockingPhaseSec**                 | 0.0<=**Dumps**                  |
# |02               | 70.0<=**TablesAllocation**  | 0.0<=**TablesAllocation**<92.87           | 0.73<=**Disk**<37456369709511.11          | 1.0<=**IndexServerRestarts**    |
# |03               | None                    | None                                  | 99320.0<=**LargestTableSize**<719737088.0 | 1.38<=**InstanceMEM**<97.15     |
# |04               | None                   | None                                  |1.0<=**LogSegmentChange**                  | 0.0<=**NameServerRestarts**<2.0 |
#
#
#
# Recheck on the correlation matrix, we got 5-highest correlated features as:
# - **IndexServerAllocationLimit** vs. **InstanceMEM***
# - **InstanceMEM** vs. **TablesAllocation**
# - **TablesAllocation** vs. I**ndexServerAllocationLimit**
# - **IndexServerAllocationLimit** vs. **PhysMEM**
# - **InstanceMEM** vs. **PhysMEM**
#
#
# <div class="alert alert-info">
# In short, we can see that the outcomes of Ruleset can be support by the correlation matrix as the high correlation features also appeared in the classification rules.
# </div>
#
# **Try to Name some classes based on Ruleset outcome:**
# - Check1: 'CPU Issue' as it was the only one class got CPU issue related
# - Check2: 'Instance Memory and Table Allocation' as those two features are distingished out of 5.
# - Check3: 'Log on Server' as it rules mostly related to Log of Server.
# - Check4: 'Server Operation Activities' as most of the rules related to Server's operation activities
# - Check5: 'Tables Allocation and HighPriority Alerts' as it got simple rules.
# - Check6: 'Diagnosis Files and Tables Allocation' as it got simple rules.
# - Check7: 'Time of Blocking Phase Issue'  it was the only one class got Blocking Phase Sec issue related
# - Check8: 'Server Restart' - as most of the rules related to Server Restart Activities

# %% [markdown]
# # Conclusion:

# %% [markdown]
#
# | XGBOOST outcome       | Check1 | Check2 | Check3 | Check4 | Check5 | Check6 | Check7 | Check8 |
# |-----------------------|--------|--------|--------|--------|--------|--------|--------|--------|
# | F1 Macro on Train     | 99.995 | 99.987 | 99.949 | 99.948 | 99.952 | 99.673 | 98.339 | 100    |
# | F1 Macro on Test      | 99.524 | 99.420 | 98.923 | 99.559 | 98.429 | 99.560 | 83.068 | 100    |
#
# | RULESET outcome       | Check1 | Check2 | Check3 | Check4 | Check5 | Check6 | Check7 | Check8 |
# |-----------------------|--------|--------|--------|--------|--------|--------|--------|--------|
# | F1 Macro on Train     | 99.907 | 89.686 | 94.131 | 99.820 | 98.282 | 97.969 | 82.360 | 98.66  |
# | F1 Macro on Test      | 99.408 | 94.013 | 95.465 | 99.373 | 97.884 | 98.604 | 69.293 | 71.845 |
#
#
# <div class="alert alert-info">
#     <b> Outcomes of both XGBOOST and Ruleset: </b>
#  <p>
# Apparently, XGBOOST delivered a slightly better accuracy in Check1 to Check6, otherwise, it is significantly higher in Check7 and Check8. However, the Ruleset can be explained and would be more applicable in industrial real cases.
# </div>
